# %% [markdown]
# https://youtu.be/qDrXmb2ZRjo

# %%
from tvDatafeed import TvDatafeed,Interval

# %%
# get credentials for tradingview
username = 'YourTradingViewUserName'
password = 'YourTradingViewPassword'

# %%
# initialize tradingview

tv=TvDatafeed(username=username,password=password)

# %%
tv.get_hist('AAPL','NASDAQ',)
# Out:
#                           symbol    open      high      low    close  \
# datetime
# 2021-04-01 19:00:00  NASDAQ:AAPL  123.66  124.1800  122.490  123.000
# 2021-04-05 19:00:00  NASDAQ:AAPL  123.87  126.1601  123.070  125.900
# 2021-04-06 19:00:00  NASDAQ:AAPL  126.50  127.1300  125.650  126.210
# 2021-04-07 19:00:00  NASDAQ:AAPL  125.83  127.9200  125.140  127.900
# 2021-04-08 19:00:00  NASDAQ:AAPL  128.95  130.3900  128.520  130.360
# 2021-04-09 19:00:00  NASDAQ:AAPL  129.80  133.0400  129.470  132.995
# 2021-04-12 19:00:00  NASDAQ:AAPL  132.52  132.8500  130.630  131.240
# 2021-04-13 19:00:00  NASDAQ:AAPL  132.44  134.6600  131.930  134.430
# 2021-04-14 19:00:00  NASDAQ:AAPL  134.94  135.0000  131.655  132.030
# 2021-04-15 19:00:00  NASDAQ:AAPL  133.82  135.0000  133.640  133.940
#
#                           volume
# datetime
# 2021-04-01 19:00:00   75089134.0
# 2021-04-05 19:00:00   88651175.0
# 2021-04-06 19:00:00   80171253.0
# 2021-04-07 19:00:00   83466716.0
# 2021-04-08 19:00:00   88844591.0
# 2021-04-09 19:00:00  106686703.0
# 2021-04-12 19:00:00   91419983.0
# 2021-04-13 19:00:00   91266545.0
# 2021-04-14 19:00:00   87200566.0
# 2021-04-15 19:00:00   41429057.0

# %%
nifty_data=tv.get_hist('NIFTY','NSE',interval=Interval.in_1_hour,n_bars=1000)

# %%
nifty_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1000 entries, 2020-09-16 09:00:00 to 2021-04-15 15:00:00
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   symbol  1000 non-null   object
#  1   open    1000 non-null   float64
#  2   high    1000 non-null   float64
#  3   low     1000 non-null   float64
#  4   close   1000 non-null   float64
#  5   volume  1000 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 54.7+ KB

# %%
nifty_data.close.plot(figsize=(10,10),use_index=False)
# Out:
# <AxesSubplot:>

# %%
# futures data
crudeoil_data=tv.get_hist('CRUDEOIL','MCX',Interval.in_2_hour,n_bars=5000,fut_contract=1)

# %%
crudeoil_data.close.plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
# cryptocurrencies
btc_data=tv.get_hist('BTC','CME',Interval.in_1_minute,n_bars=5000,fut_contract=1)

# %%
btc_usd_data=tv.get_hist('BTCUSD','BINANCE',Interval.in_1_hour,n_bars=5000)

# %%
btc_usd_data.close.plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
etheur_data=tv.get_hist('ETHEUR','BINANCE',Interval.in_1_minute,5000)

# %%
etheur_data.close.plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
# plotting candlesticks chart

import mplfinance as mpf

# %%
mpf.plot(etheur_data.head(100),type='candle',style='yahoo',volume=True)

# %%
etheur_data.to_csv('etheur.csv')
